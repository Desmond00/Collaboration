# %%
#IMPORTING ALL THE NECESSARY STANDARD LIBRARIES
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#IMPORTING LIBRARY FOR SPLITTING WHOLE DATASET INTO TRAINING AND TESTING DATA
from sklearn.model_selection import train_test_split

# %%
#IMPORTING LIBRARY FOR RECORDING TIME CONSTRAINTS
import timeit

# %%
#IMPORTING LIBRARY OF MACHINE LEARNING MODEL
from sklearn.linear_model import LinearRegression

# %%
#IMPORTING LIBRARY FOR CALCULATING STANDARD RESULTS
from sklearn import metrics

# %%
#READING DATA FROM CSV FILES INTO PADAS DATAFRAME
data = pd.read_csv('MinMaxScaledData.csv')
X = data.drop('Appliances', axis=1)
y = data['Appliances']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
#FUNCTION FOR CALCULATING RESULT IN MOST STANDARD FORMAT
def getScore(X_train, y_train, X_test, y_test) :
    startTime = timeit.default_timer()
    lg = LinearRegression()
    lg.fit(X_train, y_train)
    predictions = lg.predict(X_test)
    elapsedTime = timeit.default_timer() - startTime
    print("time taken : ",elapsedTime)
    MAE = metrics.mean_absolute_error(y_test, predictions)
    MSE = metrics.mean_squared_error(y_test, predictions)
    RMSE = np.sqrt(MSE)
    print('Mean Absolute Error : ',MAE)
    print('Mean Squared Error : ',MSE)
    print('Root Mean Squared Error : ',RMSE)
    return RMSE

# %%
datasetError = getScore(X_train, y_train, X_test, y_test)
# Out:
# time taken :  0.009511239806236915
# Mean Absolute Error :  0.04960853008772804
# Mean Squared Error :  0.007654927698355127
# Root Mean Squared Error :  0.08749244366432525

# %%
#CREATING MATRIX OF CORELATION SCORES AMONG FEATURES AND FEATURES WITH TARGET VARIABLE
scoreTable = data.corr(method='pearson')

# %%
#VISUALIZING THE MATRIX WITH COLOR STYLES
data.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <style  type="text/css" >
#     #T_09a848d4_76c0_11e8_ad84_9829a64517cerow0_col0 {
#             background-color:  #b40426;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow0_col1 {
#             background-color:  #5e7de7;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow0_col2 {
#             background-color:  #85a8fc;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow0_col3 {
#             background-color:  #6384eb;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow0_col4 {
#             background-color:  #7597f6;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow0_col5 {
#             background-color:  #4a63d3;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow0_col6 {
#             background-color:  #8caffe;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow0_col7 {
#             background-color:  #6282ea;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow0_col8 {
#             background-color:  #88abfd;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow0_col9 {
#             background-color:  #4f69d9;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow0_col10 {
#             background-color:  #90b2fe;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow0_col11 {
#             background-color:  #4f69d9;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow0_col12 {
#             background-color:  #93b5fe;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow0_col13 {
#             background-color:  #3f53c6;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow0_col14 {
#             background-color:  #6f92f3;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow0_col15 {
#             background-color:  #516ddb;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow0_col16 {
#             background-color:  #688aef;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow0_col17 {
#             background-color:  #3b4cc0;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow0_col18 {
#             background-color:  #6282ea;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow0_col19 {
#             background-color:  #506bda;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow0_col20 {
#             background-color:  #6282ea;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow0_col21 {
#             background-color:  #7a9df8;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow0_col22 {
#             background-color:  #779af7;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow0_col23 {
#             background-color:  #6b8df0;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow0_col24 {
#             background-color:  #5a78e4;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow0_col25 {
#             background-color:  #6485ec;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow0_col26 {
#             background-color:  #6485ec;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow0_col27 {
#             background-color:  #a1c0ff;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow1_col0 {
#             background-color:  #b5cdfa;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow1_col1 {
#             background-color:  #b40426;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow1_col2 {
#             background-color:  #d8dce2;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow1_col3 {
#             background-color:  #d65244;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow1_col4 {
#             background-color:  #bad0f8;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow1_col5 {
#             background-color:  #cc403a;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow1_col6 {
#             background-color:  #b3cdfb;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow1_col7 {
#             background-color:  #cf453c;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow1_col8 {
#             background-color:  #cdd9ec;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow1_col9 {
#             background-color:  #cd423b;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow1_col10 {
#             background-color:  #b7cff9;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow1_col11 {
#             background-color:  #f08a6c;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow1_col12 {
#             background-color:  #3b4cc0;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow1_col13 {
#             background-color:  #d65244;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow1_col14 {
#             background-color:  #d3dbe7;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow1_col15 {
#             background-color:  #d85646;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow1_col16 {
#             background-color:  #b9d0f9;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow1_col17 {
#             background-color:  #d55042;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow1_col18 {
#             background-color:  #c7d7f0;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow1_col19 {
#             background-color:  #ed8366;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow1_col20 {
#             background-color:  #9abbff;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow1_col21 {
#             background-color:  #6f92f3;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow1_col22 {
#             background-color:  #a7c5fe;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow1_col23 {
#             background-color:  #aac7fd;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow1_col24 {
#             background-color:  #f59f80;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow1_col25 {
#             background-color:  #b9d0f9;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow1_col26 {
#             background-color:  #b9d0f9;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow1_col27 {
#             background-color:  #c5d6f2;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow2_col0 {
#             background-color:  #a2c1ff;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow2_col1 {
#             background-color:  #b1cbfc;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow2_col2 {
#             background-color:  #b40426;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow2_col3 {
#             background-color:  #cbd8ee;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow2_col4 {
#             background-color:  #e57058;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow2_col5 {
#             background-color:  #c7d7f0;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow2_col6 {
#             background-color:  #dc5d4a;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow2_col7 {
#             background-color:  #a2c1ff;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow2_col8 {
#             background-color:  #d44e41;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow2_col9 {
#             background-color:  #bbd1f8;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow2_col10 {
#             background-color:  #d3dbe7;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow2_col11 {
#             background-color:  #d5dbe5;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow2_col12 {
#             background-color:  #c5d6f2;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow2_col13 {
#             background-color:  #8badfd;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow2_col14 {
#             background-color:  #e46e56;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow2_col15 {
#             background-color:  #7da0f9;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow2_col16 {
#             background-color:  #ee8669;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow2_col17 {
#             background-color:  #a3c2fe;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow2_col18 {
#             background-color:  #ea7b60;
#         }    #T_09a848d4_76c0_11e8_ad84_9829a64517cerow2_col19 {
#             background-color:  #dadce0;
#         }    #T_09a848d4_76c0_11e

# %%
#GETTING FEATURE INDICES
FeatureIndices = scoreTable.index.tolist()

# %%
#SORTING FEATURES W.R.T. THEIR CORELATION SCORE
def sortDic(UnsortedDictionary):
    dicItems = [(value,key) for key,value in UnsortedDictionary.items()]
    dicItems.sort()
    dicItems.reverse()
    dicItems = {key:value for value,key in dicItems}
    return dicItems

# %%
FeatureScoresForTargetVariable = {}

# %%
#GETTING FEATURE CORELATION SCORES WITH TARGET VARIABLE FROM CREATED MATRIX
for i in FeatureIndices[:-1]:
    FeatureScoresForTargetVariable[i] = scoreTable.loc[i][FeatureIndices[-1]]

# %%
#SORTING THE FEATURES ACCORDING TO THEIR SCORES WITH TARGET VARIABLE
FeatureScoresForTargetVariable = sortDic(FeatureScoresForTargetVariable)
print(FeatureScoresForTargetVariable)
# Out:
# {'lights': 0.19727755999010302, 'T2': 0.12007328295755802, 'T6': 0.11763768937551015, 'T_out': 0.09915467998032984, 'Windspeed': 0.08712210576349999, 'RH_1': 0.08603142528492509, 'T3': 0.08505990253869669, 'T1': 0.05544747194220067, 'T4': 0.040280983130662085, 'T8': 0.03957198126209111, 'RH_3': 0.03629172104744544, 'T7': 0.025801044763464398, 'T5': 0.01975986073654099, 'RH_4': 0.01696543130336212, 'Tdewpoint': 0.015356636151235312, 'T9': 0.010010284788498311, 'RH_5': 0.006954536223016289, 'Visibility': 0.00023035789593491997, 'rv2': -0.011144917497938741, 'rv1': -0.011144917497938741, 'Press_mm_hg': -0.0348848291039675, 'RH_9': -0.05146201134289545, 'RH_7': -0.055642418346175594, 'RH_2': -0.06046476002568845, 'RH_6': -0.08317760710059757, 'RH_8': -0.09403862705798324, 'RH_out': -0.1522823808333926}

# %%
#FUNCTION FOR CALCULATING ERROR VALUE OF EACH FEATURE SUBSET
errorRate = []
#FOR CHECKING THE SCORE FOR EACH SELECTED FEATURE SUBSET
def trainTestScore(X_train, y_train, X_test, y_test):
    startTime = timeit.default_timer()
    lg = LinearRegression()
    lg.fit(X_train, y_train)
    predictions = lg.predict(X_test)
    elapsedTime = timeit.default_timer() - startTime
    print("time taken : ",elapsedTime)
    error = np.sqrt(metrics.mean_squared_error(y_test, predictions))
    print('\tError rate : ',error)
    errorRate.append(error)
    return error

# %%
#FUNCTION TO GET THE BEST FEATURE TO ADD NEXT IN THE FEATURE SUBSET
Features = list(FeatureScoresForTargetVariable.keys())
def selectNextBestFeature(FeatureSubset, featureIndex) :
    while featureIndex<len(Features):
        checkFeature = Features[featureIndex]
        noMatchWithAnyone = True
        if len(FeatureSubset) == 0:
            noMatchWithAnyone = True
        else:
            for feature in FeatureSubset:
                print('feature:',feature,'\tkey:',checkFeature)
                if(scoreTable.loc[str(feature)][checkFeature] >= 0.7):
                    noMatchWithAnyone = False
                    break          
        if(noMatchWithAnyone == True):
            return checkFeature, featureIndex
        featureIndex += 1

# %%
#PROPOSED HYBRID ALGORITHM
def HybridAlgo(allowedError):
#     while noOfFeatures <=36:
    i = 0
    scores = []
    FinalSubset = []
    LeastError = 100
    featureIndex = -1
    noOfFeatures = 3
    while abs(LeastError - datasetError)>allowedError and featureIndex<len(Features)-1:
        while i<noOfFeatures and featureIndex<len(Features):
            Subset = FinalSubset[:]
            feature, featureIndex = selectNextBestFeature(FinalSubset, featureIndex+1 )
            Subset.append(feature)
            error = trainTestScore(X_train.loc[:,Subset], y_train, X_test.loc[:, Subset], y_test)
            if(error < LeastError):
                FinalSubset = Subset[:]
                LeastError = error
                i += 1
            print("feature subset : ",Subset, "error : ", error)
            print("\n\n\nBest feature subset : ",FinalSubset, "error : ", LeastError)
        noOfFeatures += 1
    return FinalSubset

# %%
#GETTING THE BEST FEATURE SUBSETS
bestFeatureSubset = HybridAlgo(0.05)
# Out:
# time taken :  0.06445843277023044
# 	Error rate :  0.09380583189833455
# feature subset :  ['lights'] error :  0.09380583189833455
#
#
#
# Best feature subset :  ['lights'] error :  0.09380583189833455
# feature: lights 	key: T2
# time taken :  0.0019359261355695878
# 	Error rate :  0.09309202560658171
# feature subset :  ['lights', 'T2'] error :  0.09309202560658171
#
#
#
# Best feature subset :  ['lights', 'T2'] error :  0.09309202560658171
# feature: lights 	key: T6
# feature: T2 	key: T6
# feature: lights 	key: T_out
# feature: T2 	key: T_out
# feature: lights 	key: Windspeed
# feature: T2 	key: Windspeed
# time taken :  0.0014808156717300847
# 	Error rate :  0.09285656642647966
# feature subset :  ['lights', 'T2', 'Windspeed'] error :  0.09285656642647966
#
#
#
# Best feature subset :  ['lights', 'T2', 'Windspeed'] error :  0.09285656642647966

# %%
#CALCULATING RESULT FOR BEST FEATURE SUBSET
getScore(X_train.loc[:,bestFeatureSubset], y_train, X_test.loc[:, bestFeatureSubset], y_test)
# Out:
# time taken :  0.0012253849239129977
# Mean Absolute Error :  0.05362291563834494
# Mean Squared Error :  0.008622341928515229
# Root Mean Squared Error :  0.09285656642647966
# 0.09285656642647966

# %% [markdown]
# <h5>Here comparatively less time(0.00139ms compared to  0.00951ms taking only 12.8% of the time taken by the whole dataset)  is taken by the algorithm with the cost of slightly higher error (0.0928 compared to 0.0874 from the whole dataset).</h5>
