# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.model_selection import train_test_split

# %%
import timeit

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn import metrics

# %%
data = pd.read_csv('MinMaxScaledData.csv')
X = data.drop('Appliances', axis=1)
y = data['Appliances']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
def getErrorScoreWithVariableK() :
    errorRate = []
    for i in range(1,40):
        knn = KNeighborsClassifier(n_neighbors = i, n_jobs=-1)
        knn.fit(X_train, y_train)
        prediction = knn.predict(X_test)
#     elapsedTime = timeit.default_timer() - startTime
#     print("time taken : ",elapsedTime)
        error = MSE = metrics.mean_squared_error(y_test, predictions)
#     print('\tError rate : ',error)
        errorRate.append(error)
    plt.plot(range(1,40), errorRate, color='blue', linestyle='dashed', marker='o',
     markerfacecolor='red', markersize=12)

# %%
getErrorScoreWithVariableK()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-f911a8cbbe35> in <module>()
# ----> 1 getErrorScoreWithVariableK()
#
# <ipython-input-9-70bbf8ffa6b8> in getErrorScoreWithVariableK()
#       3     for i in range(1,40):
#       4         knn = KNeighborsClassifier(n_neighbors = i, n_jobs=-1)
# ----> 5         knn.fit(X_train, y_train)
#       6         prediction = knn.predict(X_test)
#       7 #     elapsedTime = timeit.default_timer() - startTime
#
# D:\Anaconda\lib\site-packages\sklearn\neighbors\base.py in fit(self, X, y)
#     777             self.outputs_2d_ = True
#     778
# --> 779         check_classification_targets(y)
#     780         self.classes_ = []
#     781         self._y = np.empty(y.shape, dtype=np.int)
#
# D:\Anaconda\lib\site-packages\sklearn\utils\multiclass.py in check_classification_targets(y)
#     170     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     171                       'multilabel-indicator', 'multilabel-sequences']:
# --> 172         raise ValueError("Unknown label type: %r" % y_type)
#     173
#     174
#
# ValueError: Unknown label type: 'continuous'

# %% [markdown]
# <h3>Considering n_neighbors = 18</h3>

# %%
def getScoreMatrix(X_train, y_train, X_test, y_test) :
    startTime = timeit.default_timer()
    scaler = StandardScaler()
    scaler.fit(X_train)
    X_train = scaler.transform(X_train)
    scaler = StandardScaler()
    scaler.fit(X_test)
    X_test = scaler.transform(X_test)
    knn = KNeighborsClassifier(n_neighbors = 18, n_jobs=-1)
    knn.fit(X_train, y_train)
    prediction = knn.predict(X_test)
    elapsedTime = timeit.default_timer() - startTime
    print("time taken : ",elapsedTime)
    error = np.mean(prediction != y_test)
    print('\tError rate : ',error)
    print(confusion_matrix(y_test, prediction))
    print ('\n')
    print(classification_report(y_test, prediction))

# %%
getScoreMatrix(X_train, y_train, X_test, y_test)
# Out:
# time taken :  0.11779794802069615
# 	Error rate :  0.19491525423728814
# [[ 7 23]
#  [ 0 88]]
#
#
#              precision    recall  f1-score   support
#
#        fail       1.00      0.23      0.38        30
#        pass       0.79      1.00      0.88        88
#
# avg / total       0.85      0.81      0.76       118

# %%
scoreTable = data.corr(method='pearson')

# %%
data.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <style  type="text/css" >
#     #T_10f7dff4_7192_11e8_9875_9829a64517cerow0_col0 {
#             background-color:  #b40426;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow0_col1 {
#             background-color:  #98b9ff;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow0_col2 {
#             background-color:  #d6dce4;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow0_col3 {
#             background-color:  #abc8fd;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow0_col4 {
#             background-color:  #a2c1ff;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow0_col5 {
#             background-color:  #bbd1f8;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow0_col6 {
#             background-color:  #bed2f6;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow0_col7 {
#             background-color:  #9dbdff;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow0_col8 {
#             background-color:  #b6cefa;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow0_col9 {
#             background-color:  #b1cbfc;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow0_col10 {
#             background-color:  #a6c4fe;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow0_col11 {
#             background-color:  #b6cefa;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow0_col12 {
#             background-color:  #80a3fa;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow0_col13 {
#             background-color:  #7da0f9;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow0_col14 {
#             background-color:  #a5c3fe;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow0_col15 {
#             background-color:  #92b4fe;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow0_col16 {
#             background-color:  #a6c4fe;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow0_col17 {
#             background-color:  #9abbff;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow0_col18 {
#             background-color:  #a1c0ff;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow0_col19 {
#             background-color:  #a9c6fd;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow0_col20 {
#             background-color:  #7da0f9;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow0_col21 {
#             background-color:  #adc9fd;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow0_col22 {
#             background-color:  #82a6fb;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow0_col23 {
#             background-color:  #84a7fc;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow0_col24 {
#             background-color:  #7a9df8;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow0_col25 {
#             background-color:  #9abbff;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow0_col26 {
#             background-color:  #bbd1f8;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow0_col27 {
#             background-color:  #afcafc;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow0_col28 {
#             background-color:  #8badfd;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow0_col29 {
#             background-color:  #80a3fa;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow0_col30 {
#             background-color:  #3b4cc0;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow0_col31 {
#             background-color:  #b3cdfb;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow0_col32 {
#             background-color:  #a7c5fe;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow0_col33 {
#             background-color:  #5875e1;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow0_col34 {
#             background-color:  #aec9fc;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow0_col35 {
#             background-color:  #a3c2fe;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow0_col36 {
#             background-color:  #88abfd;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow0_col37 {
#             background-color:  #8badfd;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow0_col38 {
#             background-color:  #7597f6;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow0_col39 {
#             background-color:  #85a8fc;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow0_col40 {
#             background-color:  #a5c3fe;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow0_col41 {
#             background-color:  #afcafc;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow0_col42 {
#             background-color:  #85a8fc;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow0_col43 {
#             background-color:  #abc8fd;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow0_col44 {
#             background-color:  #9dbdff;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow0_col45 {
#             background-color:  #abc8fd;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow1_col0 {
#             background-color:  #85a8fc;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow1_col1 {
#             background-color:  #b40426;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow1_col2 {
#             background-color:  #7ea1fa;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow1_col3 {
#             background-color:  #6f92f3;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow1_col4 {
#             background-color:  #80a3fa;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow1_col5 {
#             background-color:  #5977e3;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow1_col6 {
#             background-color:  #5a78e4;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow1_col7 {
#             background-color:  #6485ec;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow1_col8 {
#             background-color:  #aac7fd;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow1_col9 {
#             background-color:  #7a9df8;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow1_col10 {
#             background-color:  #6384eb;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow1_col11 {
#             background-color:  #94b6ff;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow1_col12 {
#             background-color:  #7093f3;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow1_col13 {
#             background-color:  #5977e3;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow1_col14 {
#             background-color:  #82a6fb;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow1_col15 {
#             background-color:  #84a7fc;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow1_col16 {
#             background-color:  #8badfd;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow1_col17 {
#             background-color:  #aac7fd;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow1_col18 {
#             background-color:  #8db0fe;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow1_col19 {
#             background-color:  #8fb1fe;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow1_col20 {
#             background-color:  #86a9fc;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow1_col21 {
#             background-color:  #7295f4;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow1_col22 {
#             background-color:  #6e90f2;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow1_col23 {
#             background-color:  #8fb1fe;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow1_col24 {
#             background-color:  #85a8fc;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow1_col25 {
#             background-color:  #9abbff;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow1_col26 {
#             background-color:  #6384eb;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow1_col27 {
#             background-color:  #7b9ff9;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow1_col28 {
#             background-color:  #92b4fe;
#         }    #T_10f7dff4_7192_11e8_9875_9829a64517cerow1_col29 {
#             background-color:  #7ea1fa;
#         }    #T_10f7dff

# %%
FeatureIndices = scoreTable.index.tolist()

# %%
def sortDic(UnsortedDictionary):
    dicItems = [(value,key) for key,value in UnsortedDictionary.items()]
    dicItems.sort()
    dicItems.reverse()
    dicItems = {key:value for value,key in dicItems}
    return dicItems

# %%
FeatureScoresForTargetVariable = {}

# %%
for i in FeatureIndices[:-1]:
    FeatureScoresForTargetVariable[i] = scoreTable.loc[i][FeatureIndices[-1]]

# %%
FeatureScoresForTargetVariable = sortDic(FeatureScoresForTargetVariable)
print(FeatureScoresForTargetVariable)
# Out:
# {'G2': 0.9655825287379309, 'G1': 0.8918050309914132, 'Medu': 0.1903080728835771, 'Fedu': 0.15881054573241574, 'bin_Fjob_teacher': 0.15845502585632548, 'bin_Mjob_health': 0.1345806597857446, 'address': 0.13008983320585088, 'studytime': 0.1267280983875597, 'higher': 0.11341856892292435, 'internet': 0.11162387594711433, 'sex': 0.10244793778574587, 'bin_Mjob_services': 0.10213423770270001, 'school': 0.08361509263495502, 'activities': 0.05859950948676735, 'bin_reason_reputation': 0.05657278782032437, 'bin_Mjob_teacher': 0.04538976821280378, 'famrel': 0.03771050597869576, 'bin_guardian_father': 0.03522032525540112, 'bin_Fjob_at_home': 0.028953825854769386, 'Pstatus': 0.026664521996957544, 'nursery': 0.02654063950753391, 'bin_guardian_mother': 0.007727570406234397, 'bin_Fjob_health': 0.006241104393640157, 'bin_reason_home': 0.0003721097580944383, 'bin_reason_other': -0.003896544873950216, 'bin_Fjob_services': -0.01815445740024248, 'freetime': -0.021588660083587556, 'paid': -0.028898617892974647, 'famsize': -0.03974425787948102, 'romantic': -0.049943569939216316, 'bin_reason_course': -0.05091780486198275, 'famsup': -0.06730497848156954, 'bin_guardian_other': -0.06949086647112596, 'bin_Fjob_other': -0.0815020834407599, 'health': -0.08169095991485215, 'bin_Mjob_at_home': -0.09062395488690837, 'traveltime': -0.0997845234364179, 'age': -0.14037178289305746, 'Dalc': -0.14068976369448327, 'bin_Mjob_other': -0.1425405682864796, 'goout': -0.1773827901311216, 'Walc': -0.19005385331236407, 'absences': -0.21312853214380878, 'schoolsup': -0.23836484976174893, 'failures': -0.29383090933749184}

# %%
errorRate = []
#FOR CHECKING THE SCORE FOR EACH SELECTED FEATURE SUBSET
def trainTestScore(X_train, y_train, X_test, y_test):
    startTime = timeit.default_timer()
    scaler = StandardScaler()
    scaler.fit(X_train)
    X_train = scaler.transform(X_train)
    scaler = StandardScaler()
    scaler.fit(X_test)
    X_test = scaler.transform(X_test)
    knn = KNeighborsClassifier(n_neighbors = 18, n_jobs=-1)
    knn.fit(X_train, y_train)
    prediction = knn.predict(X_test)
    elapsedTime = timeit.default_timer() - startTime
    print("time taken : ",elapsedTime)
    error = np.mean(prediction != y_test)
    print('\tError rate : ',error)
    errorRate.append(error)
    return error

# %%
Features = list(FeatureScoresForTargetVariable.keys())
def selectNextBestFeature(FeatureSubset, featureIndex) :
    while featureIndex<len(Features):
        checkFeature = Features[featureIndex]
        noMatchWithAnyone = True
        if len(FeatureSubset) == 0:
            noMatchWithAnyone = True
        else:
            for feature in FeatureSubset:
                print('feature:',feature,'\tkey:',checkFeature)
                if(scoreTable.loc[str(feature)][checkFeature] >= 0.7):
                    noMatchWithAnyone = False
                    break          
        if(noMatchWithAnyone == True):
            return checkFeature, featureIndex
        featureIndex += 1

# %%
def scoresForFeatures():
    noOfFeatures = 3
#     while noOfFeatures <=36:
    i = 0
    scores = []
    FinalSubset = []
    LeastError = 100
    featureIndex = -1
    while i<noOfFeatures and featureIndex<len(Features):
        Subset = FinalSubset[:]
        feature, featureIndex = selectNextBestFeature(FinalSubset, featureIndex+1 )
        Subset.append(feature)
        error = trainTestScore(X_train.loc[:,Subset], y_train, X_test.loc[:, Subset], y_test)
        if(error < LeastError):
            FinalSubset = Subset[:]
            LeastError = error
            i += 1
        print("feature subset : ",Subset, "error : ", error)
        print("\n\n\nBest feature subset : ",FinalSubset, "error : ", LeastError)
    return FinalSubset

# %%
bestFeatureSubset = scoresForFeatures()
# Out:
# time taken :  0.11626820797411597
# 	Error rate :  0.11864406779661017
# feature subset :  ['G2'] error :  0.11864406779661017
#
#
#
# Best feature subset :  ['G2'] error :  0.11864406779661017
# feature: G2 	key: G1
# feature: G2 	key: Medu
# time taken :  0.11179219656222017
# 	Error rate :  0.09322033898305085
# feature subset :  ['G2', 'Medu'] error :  0.09322033898305085
#
#
#
# Best feature subset :  ['G2', 'Medu'] error :  0.09322033898305085
# feature: G2 	key: Fedu
# feature: Medu 	key: Fedu
# time taken :  0.11067319370923201
# 	Error rate :  0.13559322033898305
# feature subset :  ['G2', 'Medu', 'Fedu'] error :  0.13559322033898305
#
#
#
# Best feature subset :  ['G2', 'Medu'] error :  0.09322033898305085
# feature: G2 	key: bin_Fjob_teacher
# feature: Medu 	key: bin_Fjob_teacher
# time taken :  0.12959498013157145
# 	Error rate :  0.09322033898305085
# feature subset :  ['G2', 'Medu', 'bin_Fjob_teacher'] error :  0.09322033898305085
#
#
#
# Best feature subset :  ['G2', 'Medu'] error :  0.09322033898305085
# feature: G2 	key: bin_Mjob_health
# feature: Medu 	key: bin_Mjob_health
# time taken :  0.12176252904885132
# 	Error rate :  0.1016949152542373
# feature subset :  ['G2', 'Medu', 'bin_Mjob_health'] error :  0.1016949152542373
#
#
#
# Best feature subset :  ['G2', 'Medu'] error :  0.09322033898305085
# feature: G2 	key: address
# feature: Medu 	key: address
# time taken :  0.11594564843284161
# 	Error rate :  0.11016949152542373
# feature subset :  ['G2', 'Medu', 'address'] error :  0.11016949152542373
#
#
#
# Best feature subset :  ['G2', 'Medu'] error :  0.09322033898305085
# feature: G2 	key: studytime
# feature: Medu 	key: studytime
# time taken :  0.11260001763551486
# 	Error rate :  0.09322033898305085
# feature subset :  ['G2', 'Medu', 'studytime'] error :  0.09322033898305085
#
#
#
# Best feature subset :  ['G2', 'Medu'] error :  0.09322033898305085
# feature: G2 	key: higher
# feature: Medu 	key: higher
# time taken :  0.12299417174162386
# 	Error rate :  0.11016949152542373
# feature subset :  ['G2', 'Medu', 'higher'] error :  0.11016949152542373
#
#
#
# Best feature subset :  ['G2', 'Medu'] error :  0.09322033898305085
# feature: G2 	key: internet
# feature: Medu 	key: internet
# time taken :  0.12034656661822396
# 	Error rate :  0.06779661016949153
# feature subset :  ['G2', 'Medu', 'internet'] error :  0.06779661016949153
#
#
#
# Best feature subset :  ['G2', 'Medu', 'internet'] error :  0.06779661016949153

# %%
getScoreMatrix(X_train.loc[:,bestFeatureSubset], y_train, X_test.loc[:, bestFeatureSubset], y_test)
# Out:
# time taken :  0.10831572150652846
# 	Error rate :  0.059322033898305086
# [[25  5]
#  [ 2 86]]
#
#
#              precision    recall  f1-score   support
#
#        fail       0.93      0.83      0.88        30
#        pass       0.95      0.98      0.96        88
#
# avg / total       0.94      0.94      0.94       118

# %% [markdown]
# <h5>Here comparatively less time(0.108ms compared to 0.117ms time taken by the whole dataset)  is taken by the algorithm.</h5>
# <h5>The algorithm returned feature subset produces a higher precision(0.94 compared to 0.85 from the whole dataset).</h5>
