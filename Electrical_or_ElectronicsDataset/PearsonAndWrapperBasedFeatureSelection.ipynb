# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.model_selection import train_test_split

# %%
import timeit

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn import metrics

# %%
data = pd.read_csv('MinMaxScaledData.csv')
X = data.drop('Appliances', axis=1)
y = data['Appliances']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
def getScore(X_train, y_train, X_test, y_test) :
    startTime = timeit.default_timer()
    scaler = StandardScaler()
    scaler.fit(X_train)
    X_train = scaler.transform(X_train)
    scaler = StandardScaler()
    scaler.fit(X_test)
    X_test = scaler.transform(X_test)
    lg = LinearRegression()
    lg.fit(X_train, y_train)
    predictions = lg.predict(X_test)
    elapsedTime = timeit.default_timer() - startTime
    print("time taken : ",elapsedTime)
    MAE = metrics.mean_absolute_error(y_test, predictions)
    MSE = metrics.mean_squared_error(y_test, predictions)
    RMSE = np.sqrt(MSE)
    print('Mean Absolute Error : ',MAE)
    print('Mean Squared Error : ',MSE)
    print('Root Mean Squared Error : ',RMSE)

# %%
getScore(X_train, y_train, X_test, y_test)
# Out:
# time taken :  0.06671578067084738
# Mean Absolute Error :  0.04936621336758118
# Mean Squared Error :  0.0076519014212262666
# Root Mean Squared Error :  0.08747514744901129

# %%
scoreTable = data.corr(method='pearson')

# %%
data.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <style  type="text/css" >
#     #T_17e02310_7215_11e8_81e3_9829a64517cerow0_col0 {
#             background-color:  #b40426;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow0_col1 {
#             background-color:  #cedaeb;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow0_col2 {
#             background-color:  #afcafc;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow0_col3 {
#             background-color:  #e7745b;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow0_col4 {
#             background-color:  #bfd3f6;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow0_col5 {
#             background-color:  #f5a081;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow0_col6 {
#             background-color:  #c0d4f5;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow0_col7 {
#             background-color:  #da5a49;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow0_col8 {
#             background-color:  #81a4fb;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow0_col9 {
#             background-color:  #dc5d4a;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow0_col10 {
#             background-color:  #a1c0ff;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow0_col11 {
#             background-color:  #dd5f4b;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow0_col12 {
#             background-color:  #a6c4fe;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow0_col13 {
#             background-color:  #f08b6e;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow0_col14 {
#             background-color:  #3b4cc0;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow0_col15 {
#             background-color:  #d44e41;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow0_col16 {
#             background-color:  #b2ccfb;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow0_col17 {
#             background-color:  #dc5d4a;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow0_col18 {
#             background-color:  #9ebeff;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow0_col19 {
#             background-color:  #ca3b37;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow0_col20 {
#             background-color:  #a5c3fe;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow0_col21 {
#             background-color:  #f18f71;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow0_col22 {
#             background-color:  #cbd8ee;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow0_col23 {
#             background-color:  #93b5fe;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow0_col24 {
#             background-color:  #a2c1ff;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow0_col25 {
#             background-color:  #c0d4f5;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow0_col26 {
#             background-color:  #f7a98b;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow0_col27 {
#             background-color:  #cfdaea;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow0_col28 {
#             background-color:  #cfdaea;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow1_col0 {
#             background-color:  #6180e9;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow1_col1 {
#             background-color:  #b40426;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow1_col2 {
#             background-color:  #9fbfff;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow1_col3 {
#             background-color:  #7597f6;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow1_col4 {
#             background-color:  #7da0f9;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow1_col5 {
#             background-color:  #88abfd;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow1_col6 {
#             background-color:  #536edd;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow1_col7 {
#             background-color:  #7da0f9;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow1_col8 {
#             background-color:  #6e90f2;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow1_col9 {
#             background-color:  #6f92f3;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow1_col10 {
#             background-color:  #688aef;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow1_col11 {
#             background-color:  #6a8bef;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow1_col12 {
#             background-color:  #6687ed;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow1_col13 {
#             background-color:  #86a9fc;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow1_col14 {
#             background-color:  #4c66d6;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow1_col15 {
#             background-color:  #6b8df0;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow1_col16 {
#             background-color:  #5470de;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow1_col17 {
#             background-color:  #6f92f3;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow1_col18 {
#             background-color:  #4961d2;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow1_col19 {
#             background-color:  #6788ee;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow1_col20 {
#             background-color:  #5572df;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow1_col21 {
#             background-color:  #81a4fb;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow1_col22 {
#             background-color:  #5a78e4;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow1_col23 {
#             background-color:  #3b4cc0;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow1_col24 {
#             background-color:  #7ea1fa;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow1_col25 {
#             background-color:  #6384eb;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow1_col26 {
#             background-color:  #688aef;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow1_col27 {
#             background-color:  #6180e9;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow1_col28 {
#             background-color:  #6180e9;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow2_col0 {
#             background-color:  #3b4cc0;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow2_col1 {
#             background-color:  #a7c5fe;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow2_col2 {
#             background-color:  #b40426;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow2_col3 {
#             background-color:  #6687ed;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow2_col4 {
#             background-color:  #8caffe;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow2_col5 {
#             background-color:  #6b8df0;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow2_col6 {
#             background-color:  #7b9ff9;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow2_col7 {
#             background-color:  #516ddb;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow2_col8 {
#             background-color:  #94b6ff;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow2_col9 {
#             background-color:  #6a8bef;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow2_col10 {
#             background-color:  #8fb1fe;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow2_col11 {
#             background-color:  #5673e0;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow2_col12 {
#             background-color:  #97b8ff;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow2_col13 {
#             background-color:  #5673e0;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow2_col14 {
#             background-color:  #9abbff;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow2_col15 {
#             background-color:  #485fd1;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow2_col16 {
#             background-color:  #779af7;
#         }    #T_17e02310_7215_11e8_81e3_9829a64517cerow2_col17 {
#             background-color:  #5977e3;
#         }    #T_17e02310_7215_11e

# %%
FeatureIndices = scoreTable.index.tolist()

# %%
def sortDic(UnsortedDictionary):
    dicItems = [(value,key) for key,value in UnsortedDictionary.items()]
    dicItems.sort()
    dicItems.reverse()
    dicItems = {key:value for value,key in dicItems}
    return dicItems

# %%
FeatureScoresForTargetVariable = {}

# %%
for i in FeatureIndices[:-1]:
    FeatureScoresForTargetVariable[i] = scoreTable.loc[i][FeatureIndices[-1]]

# %%
FeatureScoresForTargetVariable = sortDic(FeatureScoresForTargetVariable)
print(FeatureScoresForTargetVariable)
# Out:
# {'rv1': 1.0, 'RH_out': 0.020440677989887194, 'RH_6': 0.011671356607227864, 'RH_2': 0.006274721420446199, 'RH_8': 0.004479663880348605, 'RH_7': 0.0018197097244170742, 'Press_mm_hg': 0.0006994628686143647, 'lights': 0.0005211145475995473, 'Unnamed: 0': 0.0002767759275834023, 'RH_3': -0.00047746661879620233, 'RH_1': -0.0006993158716300153, 'T9': -0.001227152784178838, 'RH_4': -0.0017865022666929298, 'T4': -0.001814683501881885, 'RH_9': -0.0029545009141303926, 'T8': -0.003210299136853345, 'T7': -0.003899654480701556, 'Tdewpoint': -0.003950344994781031, 'T3': -0.0051944444404550035, 'T5': -0.005490221143687724, 'Visibility': -0.0058885619417277804, 'T1': -0.006203015240115718, 'RH_5': -0.011056224233276946, 'T2': -0.01108735158024511, 'Appliances': -0.011144917533741548, 'Windspeed': -0.01134182833285642, 'T6': -0.015086186713735456, 'T_out': -0.015258810905309127}

# %%
errorRate = []
#FOR CHECKING THE SCORE FOR EACH SELECTED FEATURE SUBSET
def trainTestScore(X_train, y_train, X_test, y_test):
    startTime = timeit.default_timer()
    scaler = StandardScaler()
    scaler.fit(X_train)
    X_train = scaler.transform(X_train)
    scaler = StandardScaler()
    scaler.fit(X_test)
    X_test = scaler.transform(X_test)
    lg = LinearRegression()
    lg.fit(X_train, y_train)
    predictions = lg.predict(X_test)
    elapsedTime = timeit.default_timer() - startTime
    print("time taken : ",elapsedTime)
    error = metrics.mean_squared_error(y_test, predictions)
    print('\tError rate : ',error)
    errorRate.append(error)
    return error

# %%
Features = list(FeatureScoresForTargetVariable.keys())
def selectNextBestFeature(FeatureSubset, featureIndex) :
    while featureIndex<len(Features):
        checkFeature = Features[featureIndex]
        noMatchWithAnyone = True
        if len(FeatureSubset) == 0:
            noMatchWithAnyone = True
        else:
            for feature in FeatureSubset:
                print('feature:',feature,'\tkey:',checkFeature)
                if(scoreTable.loc[str(feature)][checkFeature] >= 0.7):
                    noMatchWithAnyone = False
                    break          
        if(noMatchWithAnyone == True):
            return checkFeature, featureIndex
        featureIndex += 1

# %%
def scoresForFeatures():
    noOfFeatures = 3
#     while noOfFeatures <=36:
    i = 0
    scores = []
    FinalSubset = []
    LeastError = 100
    featureIndex = -1
    while i<noOfFeatures and featureIndex<len(Features):
        Subset = FinalSubset[:]
        feature, featureIndex = selectNextBestFeature(FinalSubset, featureIndex+1 )
        Subset.append(feature)
        error = trainTestScore(X_train.loc[:,Subset], y_train, X_test.loc[:, Subset], y_test)
        if(error < LeastError):
            FinalSubset = Subset[:]
            LeastError = error
            i += 1
        print("feature subset : ",Subset, "error : ", error)
        print("\n\n\nBest feature subset : ",FinalSubset, "error : ", LeastError)
    return FinalSubset

# %%
bestFeatureSubset = scoresForFeatures()
# Out:
# time taken :  0.12487662239777819
# 	Error rate :  0.009151267198559571
# feature subset :  ['rv1'] error :  0.009151267198559571
#
#
#
# Best feature subset :  ['rv1'] error :  0.009151267198559571
# feature: rv1 	key: RH_out
# time taken :  0.006930763476248103
# 	Error rate :  0.0089255530169162
# feature subset :  ['rv1', 'RH_out'] error :  0.0089255530169162
#
#
#
# Best feature subset :  ['rv1', 'RH_out'] error :  0.0089255530169162
# feature: rv1 	key: RH_6
# feature: RH_out 	key: RH_6
# feature: rv1 	key: RH_2
# feature: RH_out 	key: RH_2
# time taken :  0.00848667237448808
# 	Error rate :  0.008914905963070978
# feature subset :  ['rv1', 'RH_out', 'RH_2'] error :  0.008914905963070978
#
#
#
# Best feature subset :  ['rv1', 'RH_out', 'RH_2'] error :  0.008914905963070978

# %%
getScore(X_train.loc[:,bestFeatureSubset], y_train, X_test.loc[:, bestFeatureSubset], y_test)
# Out:
# time taken :  0.004402055961691076
# Mean Absolute Error :  0.055304303511886393
# Mean Squared Error :  0.008914905963070978
# Root Mean Squared Error :  0.09441877971606591

# %% [markdown]
# <h5>Here comparatively less time(0.0044ms compared to 0.0667ms taking only 7% of the time taken by the whole dataset)  is taken by the algorithm with the cost of slightly higher error (0.0944 compared to 0.0874 from the whole dataset).</h5>
