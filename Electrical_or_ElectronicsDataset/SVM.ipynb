# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
from sklearn.model_selection import train_test_split

# %%
import timeit

# %%
from sklearn.svm import SVR

# %%
from sklearn import metrics

# %%
def minMaxScaling(data):
    scaler = MinMaxScaler()
    scaler.fit(data)
    return pd.DataFrame(data=scaler.transform(data), columns = data.columns)

# %%
data = pd.read_csv('MinMaxScaledData.csv')
data = minMaxScaling(data)
X = data.drop('Appliances', axis=1)
y = data['Appliances']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
def getPerformanceAnalysis() :
    from sklearn.svm import SVR
    svr_rbf = SVR(kernel='rbf', C=1e3, gamma=0.1)
    svr_lin = SVR(kernel='linear', C=1e3)
    svr_poly = SVR(kernel='poly', C=1e3, degree=3)
    y_rbf = svr_rbf.fit(X_train, y_train).predict(X_test)
    y_lin = svr_lin.fit(X_train, y_train).predict(X_test)
    y_poly = svr_poly.fit(X_train, y_train).predict(X_test)
    errorRBF = np.mean(metrics.mean_squared_error(y_test, y_rbf))
    errorLIN = np.mean(metrics.mean_squared_error(y_test, y_lin))
    errorPOLY = np.mean(metrics.mean_squared_error(y_test, y_poly))
    print('error using rbf : ', errorRBF)
    print('error using linear ; ', errorLIN)
    print('error using polynomial : ', errorPOLY)

# %%
getPerformanceAnalysis()
# Out:
# error using rbf :  0.007581661914881953
# error using linear ;  0.009776731642339066
# error using polynomial :  0.008949654393466948

# %% [markdown]
# <h3>Considering kernel RBF which is producing least error</h3>

# %%
def getScore(X_train, y_train, X_test, y_test) :
    startTime = timeit.default_timer()
    scaler = StandardScaler()
    scaler.fit(X_train)
    X_train = scaler.transform(X_train)
    scaler = StandardScaler()
    scaler.fit(X_test)
    X_test = scaler.transform(X_test)
    svr = SVR(kernel='rbf')
    svr.fit(X_train, y_train)
    predictions = svr.predict(X_test)
    elapsedTime = timeit.default_timer() - startTime
    print("time taken : ",elapsedTime)
    RMSE = np.sqrt(metrics.mean_squared_error(y_test, predictions))
    print('Root Mean Squared Error : ',RMSE)

# %%
getScore(X_train, y_train, X_test, y_test)
# Out:
# time taken :  6.469637020960683
# Root Mean Squared Error :  0.09185121045720908

# %%
scoreTable = data.corr(method='pearson')

# %%
data.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <style  type="text/css" >
#     #T_8fabf750_7379_11e8_a915_9829a64517cerow0_col0 {
#             background-color:  #b40426;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow0_col1 {
#             background-color:  #5e7de7;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow0_col2 {
#             background-color:  #85a8fc;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow0_col3 {
#             background-color:  #6384eb;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow0_col4 {
#             background-color:  #7597f6;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow0_col5 {
#             background-color:  #4a63d3;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow0_col6 {
#             background-color:  #8caffe;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow0_col7 {
#             background-color:  #6282ea;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow0_col8 {
#             background-color:  #88abfd;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow0_col9 {
#             background-color:  #4f69d9;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow0_col10 {
#             background-color:  #90b2fe;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow0_col11 {
#             background-color:  #4f69d9;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow0_col12 {
#             background-color:  #93b5fe;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow0_col13 {
#             background-color:  #3f53c6;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow0_col14 {
#             background-color:  #6f92f3;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow0_col15 {
#             background-color:  #516ddb;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow0_col16 {
#             background-color:  #688aef;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow0_col17 {
#             background-color:  #3b4cc0;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow0_col18 {
#             background-color:  #6282ea;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow0_col19 {
#             background-color:  #506bda;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow0_col20 {
#             background-color:  #6282ea;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow0_col21 {
#             background-color:  #7a9df8;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow0_col22 {
#             background-color:  #779af7;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow0_col23 {
#             background-color:  #6b8df0;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow0_col24 {
#             background-color:  #5a78e4;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow0_col25 {
#             background-color:  #6485ec;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow0_col26 {
#             background-color:  #6485ec;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow0_col27 {
#             background-color:  #a1c0ff;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow1_col0 {
#             background-color:  #b5cdfa;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow1_col1 {
#             background-color:  #b40426;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow1_col2 {
#             background-color:  #d8dce2;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow1_col3 {
#             background-color:  #d65244;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow1_col4 {
#             background-color:  #bad0f8;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow1_col5 {
#             background-color:  #cc403a;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow1_col6 {
#             background-color:  #b3cdfb;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow1_col7 {
#             background-color:  #cf453c;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow1_col8 {
#             background-color:  #cdd9ec;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow1_col9 {
#             background-color:  #cd423b;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow1_col10 {
#             background-color:  #b7cff9;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow1_col11 {
#             background-color:  #f08a6c;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow1_col12 {
#             background-color:  #3b4cc0;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow1_col13 {
#             background-color:  #d65244;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow1_col14 {
#             background-color:  #d3dbe7;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow1_col15 {
#             background-color:  #d85646;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow1_col16 {
#             background-color:  #b9d0f9;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow1_col17 {
#             background-color:  #d55042;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow1_col18 {
#             background-color:  #c7d7f0;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow1_col19 {
#             background-color:  #ed8366;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow1_col20 {
#             background-color:  #9abbff;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow1_col21 {
#             background-color:  #6f92f3;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow1_col22 {
#             background-color:  #a7c5fe;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow1_col23 {
#             background-color:  #aac7fd;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow1_col24 {
#             background-color:  #f59f80;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow1_col25 {
#             background-color:  #b9d0f9;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow1_col26 {
#             background-color:  #b9d0f9;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow1_col27 {
#             background-color:  #c5d6f2;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow2_col0 {
#             background-color:  #a2c1ff;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow2_col1 {
#             background-color:  #b1cbfc;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow2_col2 {
#             background-color:  #b40426;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow2_col3 {
#             background-color:  #cbd8ee;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow2_col4 {
#             background-color:  #e57058;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow2_col5 {
#             background-color:  #c7d7f0;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow2_col6 {
#             background-color:  #dc5d4a;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow2_col7 {
#             background-color:  #a2c1ff;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow2_col8 {
#             background-color:  #d44e41;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow2_col9 {
#             background-color:  #bbd1f8;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow2_col10 {
#             background-color:  #d3dbe7;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow2_col11 {
#             background-color:  #d5dbe5;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow2_col12 {
#             background-color:  #c5d6f2;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow2_col13 {
#             background-color:  #8badfd;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow2_col14 {
#             background-color:  #e46e56;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow2_col15 {
#             background-color:  #7da0f9;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow2_col16 {
#             background-color:  #ee8669;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow2_col17 {
#             background-color:  #a3c2fe;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow2_col18 {
#             background-color:  #ea7b60;
#         }    #T_8fabf750_7379_11e8_a915_9829a64517cerow2_col19 {
#             background-color:  #dadce0;
#         }    #T_8fabf750_7379_11e

# %%
FeatureIndices = scoreTable.index.tolist()

# %%
def sortDic(UnsortedDictionary):
    dicItems = [(value,key) for key,value in UnsortedDictionary.items()]
    dicItems.sort()
    dicItems.reverse()
    dicItems = {key:value for value,key in dicItems}
    return dicItems

# %%
FeatureScoresForTargetVariable = {}

# %%
for i in FeatureIndices[:-1]:
    FeatureScoresForTargetVariable[i] = scoreTable.loc[i][FeatureIndices[-1]]

# %%
FeatureScoresForTargetVariable = sortDic(FeatureScoresForTargetVariable)
print(FeatureScoresForTargetVariable)
# Out:
# {'lights': 0.19727755999010302, 'T2': 0.12007328295755802, 'T6': 0.11763768937551015, 'T_out': 0.09915467998032984, 'Windspeed': 0.08712210576349999, 'RH_1': 0.08603142528492509, 'T3': 0.08505990253869669, 'T1': 0.05544747194220067, 'T4': 0.040280983130662085, 'T8': 0.03957198126209111, 'RH_3': 0.03629172104744544, 'T7': 0.025801044763464398, 'T5': 0.01975986073654099, 'RH_4': 0.01696543130336212, 'Tdewpoint': 0.015356636151235312, 'T9': 0.010010284788498311, 'RH_5': 0.006954536223016289, 'Visibility': 0.00023035789593491997, 'rv2': -0.011144917497938741, 'rv1': -0.011144917497938741, 'Press_mm_hg': -0.0348848291039675, 'RH_9': -0.05146201134289545, 'RH_7': -0.055642418346175594, 'RH_2': -0.06046476002568845, 'RH_6': -0.08317760710059757, 'RH_8': -0.09403862705798324, 'RH_out': -0.1522823808333926}

# %%
errorRate = []
#FOR CHECKING THE SCORE FOR EACH SELECTED FEATURE SUBSET
def trainTestScore(X_train, y_train, X_test, y_test):
    startTime = timeit.default_timer()
    scaler = StandardScaler()
    scaler.fit(X_train)
    X_train = scaler.transform(X_train)
    scaler = StandardScaler()
    scaler.fit(X_test)
    X_test = scaler.transform(X_test)
    svr = SVR(kernel='rbf')
    svr.fit(X_train, y_train)
    predictions = svr.predict(X_test)
    elapsedTime = timeit.default_timer() - startTime
    print("time taken : ",elapsedTime)
    error = np.sqrt(metrics.mean_squared_error(y_test, predictions))
    print('\tError rate : ',error)
    errorRate.append(error)
    return error

# %%
Features = list(FeatureScoresForTargetVariable.keys())
def selectNextBestFeature(FeatureSubset, featureIndex) :
    while featureIndex<len(Features):
        checkFeature = Features[featureIndex]
        noMatchWithAnyone = True
        if len(FeatureSubset) == 0:
            noMatchWithAnyone = True
        else:
            for feature in FeatureSubset:
                print('feature:',feature,'\tkey:',checkFeature)
                if(scoreTable.loc[str(feature)][checkFeature] >= 0.7):
                    noMatchWithAnyone = False
                    break          
        if(noMatchWithAnyone == True):
            return checkFeature, featureIndex
        featureIndex += 1

# %%
def scoresForFeatures():
    noOfFeatures = 3
#     while noOfFeatures <=36:
    i = 0
    scores = []
    FinalSubset = []
    LeastError = 100
    featureIndex = -1
    while i<noOfFeatures and featureIndex<len(Features)-1:
        Subset = FinalSubset[:]
        feature, featureIndex = selectNextBestFeature(FinalSubset, featureIndex+1 )
        Subset.append(feature)
        error = trainTestScore(X_train.loc[:,Subset], y_train, X_test.loc[:, Subset], y_test)
        if(error < LeastError):
            FinalSubset = Subset[:]
            LeastError = error
            i += 1
        print("feature subset : ",Subset, "error : ", error)
        print("\n\n\nBest feature subset : ",FinalSubset, "error : ", LeastError)
    if(i<noOfFeatures):
        print("ONLY ",i," NO OF FEATURES HAS BEEN SELECTED, AS THIS SUBSET IS PRODUCING THE LOWEST POSSIBLE ERROR")
    return FinalSubset

# %%
bestFeatureSubset = scoresForFeatures()
# Out:
# time taken :  2.4097359505977636
# 	Error rate :  0.10296744599434819
# feature subset :  ['lights'] error :  0.10296744599434819
#
#
#
# Best feature subset :  ['lights'] error :  0.10296744599434819
# feature: lights 	key: T2
# time taken :  3.182187545333278
# 	Error rate :  0.10449866620001165
# feature subset :  ['lights', 'T2'] error :  0.10449866620001165
#
#
#
# Best feature subset :  ['lights'] error :  0.10296744599434819
# feature: lights 	key: T6
# time taken :  3.619014515179373
# 	Error rate :  0.10439856479106659
# feature subset :  ['lights', 'T6'] error :  0.10439856479106659
#
#
#
# Best feature subset :  ['lights'] error :  0.10296744599434819
# feature: lights 	key: T_out
# time taken :  3.2539624476978304
# 	Error rate :  0.10429620068637785
# feature subset :  ['lights', 'T_out'] error :  0.10429620068637785
#
#
#
# Best feature subset :  ['lights'] error :  0.10296744599434819
# feature: lights 	key: Windspeed
# time taken :  2.7773770277304664
# 	Error rate :  0.10396968897797278
# feature subset :  ['lights', 'Windspeed'] error :  0.10396968897797278
#
#
#
# Best feature subset :  ['lights'] error :  0.10296744599434819
# feature: lights 	key: RH_1
# time taken :  3.3838521118547646
# 	Error rate :  0.10391449731727419
# feature subset :  ['lights', 'RH_1'] error :  0.10391449731727419
#
#
#
# Best feature subset :  ['lights'] error :  0.10296744599434819
# feature: lights 	key: T3
# time taken :  3.5404283158352996
# 	Error rate :  0.10396660984595307
# feature subset :  ['lights', 'T3'] error :  0.10396660984595307
#
#
#
# Best feature subset :  ['lights'] error :  0.10296744599434819
# feature: lights 	key: T1
# time taken :  3.012439306752981
# 	Error rate :  0.10434143146627714
# feature subset :  ['lights', 'T1'] error :  0.10434143146627714
#
#
#
# Best feature subset :  ['lights'] error :  0.10296744599434819
# feature: lights 	key: T4
# time taken :  3.198292197984415
# 	Error rate :  0.10447663788660277
# feature subset :  ['lights', 'T4'] error :  0.10447663788660277
#
#
#
# Best feature subset :  ['lights'] error :  0.10296744599434819
# feature: lights 	key: T8
# time taken :  3.2812929688277848
# 	Error rate :  0.10463476977307443
# feature subset :  ['lights', 'T8'] error :  0.10463476977307443
#
#
#
# Best feature subset :  ['lights'] error :  0.10296744599434819
# feature: lights 	key: RH_3
# time taken :  3.2557481873803624
# 	Error rate :  0.10388602826470028
# feature subset :  ['lights', 'RH_3'] error :  0.10388602826470028
#
#
#
# Best feature subset :  ['lights'] error :  0.10296744599434819
# feature: lights 	key: T7
# time taken :  3.217601397189128
# 	Error rate :  0.10433654167245363
# feature subset :  ['lights', 'T7'] error :  0.10433654167245363
#
#
#
# Best feature subset :  ['lights'] error :  0.10296744599434819
# feature: lights 	key: T5
# time taken :  3.148667521895078
# 	Error rate :  0.10432221170715437
# feature subset :  ['lights', 'T5'] error :  0.10432221170715437
#
#
#
# Best feature subset :  ['lights'] error :  0.10296744599434819
# feature: lights 	key: RH_4
# time taken :  3.354184029604909
# 	Error rate :  0.10380341858658884
# feature subset :  ['lights', 'RH_4'] error :  0.10380341858658884
#
#
#
# Best feature subset :  ['lights'] error :  0.10296744599434819
# feature: lights 	key: Tdewpoint
# time taken :  3.628898376677853
# 	Error rate :  0.10437694624645467
# feature subset :  ['lights', 'Tdewpoint'] error :  0.10437694624645467
#
#
#
# Best feature subset :  ['lights'] error :  0.10296744599434819
# feature: lights 	key: T9
# time taken :  3.335352127499192
# 	Error rate :  0.10476744927629758
# feature subset :  ['lights', 'T9'] error :  0.10476744927629758
#
#
#
# Best feature subset :  ['lights'] error :  0.10296744599434819
# feature: lights 	key: RH_5
# time taken :  3.719482994513072
# 	Error rate :  0.10458707867940294
# feature subset :  ['lights', 'RH_5'] error :  0.10458707867940294
#
#
#
# Best feature subset :  ['lights'] error :  0.10296744599434819
# feature: lights 	key: Visibility
# time taken :  2.8544181270497972
# 	Error rate :  0.10461867494350073
# feature subset :  ['lights', 'Visibility'] error :  0.10461867494350073
#
#
#
# Best feature subset :  ['lights'] error :  0.10296744599434819
# feature: lights 	key: rv2
# time taken :  3.675594985820453
# 	Error rate :  0.10456335993288829
# feature subset :  ['lights', 'rv2'] error :  0.10456335993288829
#
#
#
# Best feature subset :  ['lights'] error :  0.10296744599434819
# feature: lights 	key: rv1
# time taken :  3.7217266890998246
# 	Error rate :  0.10456335993288829
# feature subset :  ['lights', 'rv1'] error :  0.10456335993288829
#
#
#
# Best feature subset :  ['lights'] error :  0.10296744599434819
# feature: lights 	key: Press_mm_hg
# time taken :  3.6114761792338754
# 	Error rate :  0.10448713119837892
# feature subset :  ['lights', 'Press_mm_hg'] error :  0.10448713119837892
#
#
#
# Best feature subset :  ['lights'] error :  0.10296744599434819
# feature: lights 	key: RH_9
# time taken :  3.469041964029202
# 	Error rate :  0.1036406453375503
# feature subset :  ['lights', 'RH_9'] error :  0.1036406453375503
#
#
#
# Best feature subset :  ['lights'] error :  0.10296744599434819
# feature: lights 	key: RH_7
# time taken :  3.6284523684232965
# 	Error rate :  0.10376076968527764
# feature subset :  ['lights', 'RH_7'] error :  0.10376076968527764
#
#
#
# Best feature subset :  ['lights'] error :  0.10296744599434819
# feature: lights 	key: RH_2
# time taken :  3.6381991278945804
# 	Error rate :  0.10408590852500793
# feature subset :  ['lights', 'RH_2'] error :  0.10408590852500793
#
#
#
# Best feature subset :  ['lights'] error :  0.10296744599434819
# feature: lights 	key: RH_6
# time taken :  3.6083148681744035
# 	Error rate :  0.10411090526912588
# feature subset :  ['lights', 'RH_6'] error :  0.10411090526912588
#
#
#
# Best feature subset :  ['lights'] error :  0.10296744599434819
# feature: lights 	key: RH_8
# time taken :  3.7948817139459834
# 	Error rate :  0.10365508257498726
# feature subset :  ['lights', 'RH_8'] error :  0.10365508257498726
#
#
#
# Best feature subset :  ['lights'] error :  0.10296744599434819
# feature: lights 	key: RH_out
# time taken :  3.1094819420701185
# 	Error rate :  0.10356284673493941
# feature subset :  ['lights', 'RH_out'] error :  0.10356284673493941
#
#
#
# Best feature subset :  ['lights'] error :  0.10296744599434819
# ONLY  1  NO OF FEATURES HAS BEEN SELECTED, AS THIS SUBSET IS PRODUCING THE LOWEST POSSIBLE ERROR

# %%
getScore(X_train.loc[:,bestFeatureSubset], y_train, X_test.loc[:, bestFeatureSubset], y_test)
# Out:
# time taken :  2.3117557877251045
# Root Mean Squared Error :  0.10296744599434819

# %% [markdown]
# <h5>Here comparatively less time(0.0044ms compared to 0.0667ms taking only 7% of the time taken by the whole dataset)  is taken by the algorithm with the cost of slightly higher error (0.0944 compared to 0.0874 from the whole dataset).</h5>
